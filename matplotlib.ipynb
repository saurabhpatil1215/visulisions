# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(1,10,(200))

# %%
x
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518,
#         1.45226131,  1.49748744,  1.54271357,  1.5879397 ,  1.63316583,
#         1.67839196,  1.72361809,  1.76884422,  1.81407035,  1.85929648,
#         1.90452261,  1.94974874,  1.99497487,  2.04020101,  2.08542714,
#         2.13065327,  2.1758794 ,  2.22110553,  2.26633166,  2.31155779,
#         2.35678392,  2.40201005,  2.44723618,  2.49246231,  2.53768844,
#         2.58291457,  2.6281407 ,  2.67336683,  2.71859296,  2.7638191 ,
#         2.80904523,  2.85427136,  2.89949749,  2.94472362,  2.98994975,
#         3.03517588,  3.08040201,  3.12562814,  3.17085427,  3.2160804 ,
#         3.26130653,  3.30653266,  3.35175879,  3.39698492,  3.44221106,
#         3.48743719,  3.53266332,  3.57788945,  3.62311558,  3.66834171,
#         3.71356784,  3.75879397,  3.8040201 ,  3.84924623,  3.89447236,
# ...

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is x data with 1 to 10")
plt.ylabel("This is y data with sin of x")
plt.title("Sin wave")
plt.show()

# %%
x1=np.random.rand(50)
print(x1)
y1=np.random.rand(50)
print(y1)
# Out:
# [0.53010955 0.59389041 0.70251788 0.07444363 0.89367976 0.1037087
#  0.95365613 0.63779394 0.36655878 0.90655702 0.78406525 0.03058957
#  0.57095383 0.68684226 0.66033237 0.87698412 0.11914886 0.55343048
#  0.58139823 0.24002045 0.65831173 0.45817985 0.08661673 0.88264178
#  0.72062287 0.10988095 0.42933189 0.85511282 0.49686748 0.09423035
#  0.76521068 0.28604924 0.67863575 0.303443   0.03924879 0.15083066
#  0.06956231 0.98191119 0.61859575 0.43549045 0.64606672 0.2560807
#  0.0582085  0.42809481 0.04598012 0.66065182 0.78525682 0.18477364
#  0.40722166 0.0339935 ]
# [0.09013571 0.6716226  0.94678826 0.00675134 0.00255987 0.68800904
#  0.27762639 0.19940734 0.13620546 0.78213676 0.67160613 0.15618297
#  0.79749036 0.32454775 0.75330633 0.52754782 0.38659083 0.91471802
#  0.90188249 0.08284048 0.78776956 0.63559314 0.88992515 0.76594042
#  0.64375577 0.07776137 0.3705607  0.89618333 0.26018074 0.66571152
#  0.94785161 0.12107603 0.52742564 0.1560401  0.9663141  0.15216826
# ...

# %%
plt.scatter(x1,y1)

# %%
plt.plot(x1,y1)

# %%
colors=np.random.rand(50)
sizes=1000*np.random.rand(50)
plt.scatter(x1,y1,c= colors, s= sizes, alpha=.5)
plt.xlabel("This is x data with 1 to 10")
plt.ylabel("This is y data with sin of x")
plt.title('this is tital')
# Out:
# Text(0.5, 1.0, 'this is tital')

# %%
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x1,y1,c= colors,s =sizes, alpha=.5)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("RandomData")
# Out:
# Text(0.5, 1.0, 'RandomData')

# %%
x2=['a','b','c','d','e']

# %%
x2=['a','b','c','d','e']
y2=np.random.rand(5)
print(y2)
plt.bar(x2,y2)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("RandomData")
# Out:
# [0.6236006  0.4166517  0.53501971 0.93556991 0.54693552]
# Text(0.5, 1.0, 'RandomData')

# %%
x2=['a','b','c','d','e']
y2=np.random.rand(5)
print(y2)
plt.barh(x2,y2)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("RandomData")
# Out:
# [0.09581406 0.93897414 0.33851834 0.44654704 0.98983969]
# Text(0.5, 1.0, 'RandomData')

# %%
x = np.linspace(1,10,200)
y = np.sin(x)
plt.figure(figsize=[6,2])
plt.plot(x,y, '--r')
plt.xlabel("This is x data with 1 to 10")
plt.ylabel("This is y data with sin of x")
plt.title("Sin wave")
plt.grid()
plt.show()

# %%
x1 = np.random.rand(50)
y1 = np.random.rand(50)
plt.scatter(x1,y1)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x1,y1,c= '#E6BF83' ,s =sizes, alpha=.5, marker='p')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("RandomData")
# Out:
# Text(0.5, 1.0, 'RandomData')

# %%
data=[1,2,3,4,5,2,3,4,1,3,4,5,2,3]

# %%
plt.hist(data, color='pink')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Random Histograph Data")
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)

fig=plt.figure().add_subplot(projection='3d')
fig.scatter(x,y,z)
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)

fig=plt.figure().add_subplot(projection='3d')
fig.plot(x,y,z)
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)

fig=plt.figure().add_subplot(projection='3d')
fig.bar(x,y,z)
plt.show()
